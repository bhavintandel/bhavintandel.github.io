# %%
# Installing dependencies
import boto3
import os

# %%
# Listing files
os.listdir('assets')
# Out:
# ['Our_plan_to_rebuild_The_UK_Government_s_COVID-19_recovery_strategy.pdf',
#  'receipt_573065707_1000.jpg',
#  '2019-ncov-factsheet.pdf']

# %%
# Creating client to access texttract
textract_client = boto3.client('textract')

# %%
with open('assets/receipt_573065707_1000.jpg', 'rb') as f:
    image = f.read()

# %%
response = textract_client.detect_document_text(
    Document={
        'Bytes': image
    })

# %%
response
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1.0,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 0.0008699676254764199, 'Y': 0.0},
#      {'X': 1.0, 'Y': 0.0008269058307632804},
#      {'X': 1.0, 'Y': 1.0},
#      {'X': 0.0, 'Y': 0.9991922974586487}]},
#    'Id': 'aa8e7d98-72da-4631-8e59-735d0d7abb39',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['54add1b2-adf1-4aee-aaac-7fabbd3e2d94',
#       'ada0677e-981d-43d4-b88a-5cbba2aa30f1',
#       'a8b9973f-e42e-46b9-8583-8e76dd1f93b2',
#       '5b49b9d8-37ed-464f-976b-11df92a16f24',
#       'f340eba1-23b9-4813-a234-d040c87346f5',
#       'd40ca0fa-93dc-47ac-9758-ae563ff1ed6c',
#       'd4761281-072f-45d0-8a7a-5589c5c2b5ce',
#       '126512b6-ca60-4753-8c02-9544ee306b10',
#       '01d0f490-6bf5-42b1-9dd0-b0588f848105',
#       '6523e871-2f5f-45fb-a295-717464a75674',
#       '07c81bd0-2913-472e-91c3-2bba82e1fbc8',
# ...

# %%
with open('assets/2019-ncov-factsheet.pdf', 'rb') as f:
    single_pdf = f.read()
